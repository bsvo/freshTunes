# %%
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Concatenates playlist csvs and then concatenates that with the big csv we downloaded

def csvCondensor(directory):
    # Reads in and concatenates data that is from Ben and friends
    alldfs = []
    for file in os.listdir("./"+directory):
        if file.startswith("good"):
            path = os.path.join("./data", file)
            csv = pd.read_csv(path)
            csv.drop(columns=csv.columns[0], axis=1,  inplace=True)
            alldfs.append(csv)
    result = pd.concat(alldfs)
    # Reads huge song csv and appends the two dfts
    bigCsv = pd.read_csv('./data/downloadedData.csv')
    bigCsv["url"] = "https://open.spotify.com/track/"+bigCsv["url"]
    listDifference = []
    for element in bigCsv.columns:
        if element not in result.columns:
            listDifference.append(element)

    # Data processing
    bigCsv = bigCsv.drop(listDifference,axis=1)
    result = pd.concat([result,bigCsv])
    result["artist"] = result["artist"].str.lower()
    result["name"] = result["name"].str.lower()
    result = result.drop_duplicates(subset='url', keep='first')
    result = result.drop_duplicates(subset=['name','artist'], keep='first')
    result = result.reset_index(drop=True)
    return result


condensed = csvCondensor('data')
condensed
# Out:
#                                             name                 artist  \
# 0                            perth - dusky remix                   kink
# 1                      fashion (with boys noize)                  kungs
# 2       dedication to house music - extended mix            dennis quin
# 3                frankenstein (feat. a$ap rocky)    swedish house mafia
# 4                                        burnin'              daft punk
# ...                                          ...                    ...
# 134894                            come back home            calum scott
# 134895                            enough for you           saint claire
# 134896                                     do it              mike stud
# 134897                                  no smoke               d savage
# 134898                                   en vida  banda los sebastianes
#
#                                                       url danceability energy  \
# 0       https://open.spotify.com/track/38mFPR6JTtMywd4...        0.564  0.834
# 1       https://open.spotify.com/track/7E5YYuHcdlIIGMq...        0.806  0.885
# 2       https://open.spotify.com/track/2Lux0SyVTI1N2lA...        0.796  0.647
# 3       https://open.spotify.com/track/3gDRZkL8YfzpZg1...        0.531  0.612
# 4       https://open.spotify.com/track/6nSOhDfZOulWp0p...         0.87  0.875
# ...                                                   ...          ...    ...
# 134894  https://open.spotify.com/track/0cvfSKcm9Veduwy...        0.601  0.801
# 134895  https://open.spotify.com/track/43MP9F7UzvfilSr...        0.387  0.249
# 134896  https://open.spotify.com/track/4TWlUuFk81NGUNK...        0.717  0.532
# 134897  https://open.spotify.com/track/5iGBXzOoRo4sBTy...        0.772   0.51
# 134898  https://open.spotify.com/track/7LNtyuekYHiZ99U...        0.715  0.734
#
#        key loudness mode speechiness acousticness instrumentalness liveness  \
# 0       10  -10.098    1      0.0571     0.000403            0.903    0.706
# 1       11    -6.19    1       0.039      0.00003            0.814   0.0779
# 2        6   -5.882    1      0.0505     0.000874             0.89    0.029
# 3        1   -7.966    1       0.306       0.0119         0.000098    0.311
# 4        6   -8.501    0       0.205        0.192            0.357   0.0804
# ...     ..      ...  ...         ...          ...              ...      ...
# 134894  11   -5.174    1      0.0323      0.00678              0.0   0.0991
# 134895   9  -13.233    1      0.0437        0.918              0.0    0.103
# 134896   8   -8.351    0       0.206         0.33              0.0   0.0997
# 134897   4    -9.67    0        0.12       0.0079              0.0    0.131
# 134898   3   -3.244    1      0.0367        0.549              0.0    0.108
#
#        valence    tempo
# 0        0.375  124.996
# 1        0.171  121.995
# 2        0.322  129.975
# 3        0.226  105.997
# 4        0.715  124.298
# ...        ...      ...
# 134894   0.289  131.049
# 134895   0.346   94.039
# 134896   0.546  156.977
# 134897  0.0755  120.049
# 134898   0.976  130.128
#
# [134899 rows x 14 columns]

# %%
# Evaluation


# playlists to retrieve similar songs to
testUpbeatTrap = pd.read_csv('./data/goodplaylist47.csv')
testSadTrap = pd.read_csv('./data/goodplaylist2.csv')
testHouse = pd.read_csv('./data/goodplaylist38.csv')

allTests = [testUpbeatTrap,testSadTrap,testHouse]
scalable_columns = [
    'danceability',
    'energy',
    'key',
    'loudness',
    'mode',
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo'
]
pd.set_option('display.max_colwidth', None)
for test in allTests:
    scaler = StandardScaler()
    # Standardizes features 
    dataScaled = scaler.fit_transform(condensed[scalable_columns])
    playlistScaled = scaler.transform(test[scalable_columns])
    # generate similarity matrix by feature
    similarity_matrix = cosine_similarity(playlistScaled,dataScaled)
    # average feature similar
    similarity_scores = similarity_matrix.mean(axis=0)
    conSim = csvCondensor('data')
    conSim['similarity_score'] = similarity_scores
    recommendations = conSim.sort_values(by='similarity_score', ascending=False)
    # Get the top N recommendations, for example, top 10
    top_recommendations = recommendations.head(15)
    print(top_recommendations[["name","artist","url"]])
# Out:
#                                                    name           artist  \
# 1252                                           mistress            gunna
# 390     xotic (feat. future, rich the kid & young thug)          dj esco
# 11255                                         no defeat            preme
# 94473                                         two packs     boyz on marz
# 76687                                           i.e.d.s          kanardo
# 48978                                      i can’t wait       coca vango
# 124522                                el anillo - remix   jennifer lopez
# 771                                           my legacy           future
# 302                         undefeated (feat. lil keed)           future
# 20975           flo rida (feat. ski mask the slump god)  higher brothers
# 38822                                    fuckin shit up     lilcj kasino
# 122711                                   do not disturb      trill sammy
# 108335      something from nothin' (feat. rich the kid)              adé
# 2714                     still runnin (feat. meek mill)         lil baby
# 128132                              where ya loyalty at     rts triplets
#
#                                                           url
# 1252    https://open.spotify.com/track/4WSbFi3yvVmaS2JGYu0h7P
# 390     https://open.spotify.com/track/4VmcVEuTlYnWcc6QksaLyw
# 11255   https://open.spotify.com/track/2z0A8rnTZ6H7aZD6HPTErf
# 94473   https://open.spotify.com/track/15NGjfJXvGBYcNOgNI9gvm
# 76687   https://open.spotify.com/track/7BzTBjKKBhfH7bFhp23AIV
# 48978   https://open.spotify.com/track/7nA01bbjZIop141ldbF1yj
# 124522  https://open.spotify.com/track/3wyMqxd4rILBpYlpQRQ58h
# 771     https://open.spotify.com/track/4V9K7DLPZNhCH77wLsAiNF
# 302     https://open.spotify.com/track/6FZjiSBSQoj1geAgXjvqez
# 20975   https://open.spotify.com/track/4rsWZTMcBNbfXr6OIeaEs5
# 38822   https://open.spotify.com/track/4H23vlNyl3938e0iYJy7J9
# 122711  https://open.spotify.com/track/4DoWCY8raZBmpAVw2CLEzw
# 108335  https://open.spotify.com/track/37pqoamiQVw95UEiiE0viQ
# 50534   https://open.spotify.com/track/0UWor6IXWYURxJ2Hys4OWj
# 77914   https://open.spotify.com/track/4WSUQttdnKHEQp6ftTNCqo
# 2524    https://open.spotify.com/track/7hU7VXRfTEwVCMesUxiP0m
# 4572    https://open.spotify.com/track/5oXkfuwL7HieiHzvmWsaGo
# 1073    https://open.spotify.com/track/2FEUloDXMvRnyfLcsrCfkw
# 63645   https://open.spotify.com/track/1oogyE4mQxE1RRscww0hM9
# 128352  https://open.spotify.com/track/63KCjeOeBni0Waop6xfqpf
# 43529   https://open.spotify.com/track/1cP6txKffPUGxwg59Bem8u
# 43976   https://open.spotify.com/track/5TaqcNH6S0jGWXbl8Jw5Z6

# %% [markdown]
# # Evaluation:
# ## User made genre & Upbeat vs. Downbeat distinctions
# ### Trap: Modern Rap/Hip-Hop that's typically basier & uses a variety of synthesized drums such as 808s
# # Upbeat Trap (used a party/gym playlist)
# ## - Energy accuracy: 14/15
# ### Incorrect placements: i.e.d.s by kanardo
# ## - Genre accuracy: 14/15
# ### Incorrect placements: el anillo - remix, by Jennifer lopez
# ## - Overall accuracy: 13/15
# # Downbeat Trap (used a trap "feels" playlist)
# ## First track's album name was "pain", which was funny & a positive indicator
# ## - Energy accuracy: 12/15
# ### Incorrect placements : Peacoat by Future, We Alive by Kris Wu & Audemars by young igi
# ## - Genre accuracy: 15/15
# ## - Overall accuracy: 13/15
# # House music (more melodic, chill subgenre of EDM)
# ## - Genre Accuracy: 15/15 were under the umbrella of EDM
# ## - Overall Accuracy: 12/15
# ### Incorrect placements : Don't Give Up by Ghastly, Gas by Top Shelf & Look At Me by krnfx

# %%
# dummy account authentication 
clientID = "6efec37cd2184e35b82519d4fda73793"
ClientSecret = "e37bf82427ef4d98b54f9e796d43c5df"

credentials = SpotifyClientCredentials(client_id=clientID, client_secret=ClientSecret)
sp = spotipy.Spotify(client_credentials_manager=credentials)

# INPUT LINK IN FOLLOWING FORMAT: https://open.spotify.com/playlist/33PIJ4bhVgkOzyW5cKepM6


def usingYourPlaylist(link,offset=0,length=20):
    playlistUri = link.split("/")[-1].split("?")[0]
    limit = 100
    
    column_names = [
        'name',
        'artist',
        'url',
        'danceability',
        'energy',
        'key',
        'loudness',
        'mode',
        'speechiness',
        'acousticness',
        'instrumentalness',
        'liveness',
        'valence',
        'tempo'
    ]
    
    scalable_columns = [
    'danceability',
    'energy',
    'key',
    'loudness',
    'mode',
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo'
    ]
    playlistDf = pd.DataFrame(columns=column_names)
    while True:
        # Fetching a batch of tracks from the playlist
        response = sp.playlist_tracks(playlistUri, offset=offset, limit=100, fields='items.track(name,artists,name,album,name,external_urls(spotify)),next')
        listOfTracks = response['items']
        lis = listOfTracks
        # Extract the track data and audio features
        for i, item in enumerate(listOfTracks):
            track = item['track']
            if 'spotify' in track['external_urls']:
                url = track['external_urls']['spotify']
                artistName = track['artists'][0]['name']
                trackName = track['name']
                try:
                    audioFeatures = sp.audio_features([url])[0]
                    time.sleep(.5)
                    rowData = [trackName, artistName,url, audioFeatures['danceability'], audioFeatures['energy'],
                               audioFeatures['key'], audioFeatures['loudness'], audioFeatures['mode'], audioFeatures['speechiness'],
                               audioFeatures['acousticness'], audioFeatures['instrumentalness'], audioFeatures['liveness'],
                               audioFeatures['valence'], audioFeatures['tempo']]
                    playlistDf.loc[len(playlistDf)] = rowData
                except spotipy.SpotifyException as e:
                    if e.http_status == 429:
                        print(e.headers)        
                        return playlistDf
        if response['next'] is not None:
            offset += limit
        else:
            break
    
    condensed = csvCondensor('data')
    scaler = StandardScaler()
    dataScaled = scaler.fit_transform(condensed[scalable_columns])
    playlistScaled = scaler.transform(playlistDf[scalable_columns])
    # generate similarity matrix by feature
    similarity_matrix = cosine_similarity(playlistScaled,dataScaled)
    # average feature similar
    similarity_scores = similarity_matrix.mean(axis=0)
    
    yourSimilarityMatrix = condensed.copy()
    yourSimilarityMatrix['similarity_score'] = similarity_scores
    recommendations = yourSimilarityMatrix.sort_values(by='similarity_score', ascending=False)
    pd.set_option('display.max_colwidth', None)
    top_recommendations = recommendations.head(length)
    return top_recommendations


# Replace the link with your playlist
# optional arguments for offset & number of songs you'd like the output playlist to be
usingYourPlaylist("https://open.spotify.com/playlist/6ZDVwQTn9IO38eORFDfnWC?si=J3jp0aOWTZCOh7O8-wBIdA")
# Out:
#                                               name  \
# 810                                       fly rich
# 67199                                  rubberbandz
# 77510                                       cherry
# 8268    take off (feat. slim dunkin & wooh da kid)
# 35280                             fish outta water
# 51683                                       gnarly
# 18810                                block st hood
# 110542                                hava tequila
# 177                                     stick talk
# 103908                                        roof
# 67124                   intro (backyard freestyle)
# 125634                  rerun (feat. travis scott)
# 3784                                     draft day
# 122973                               public figure
# 3999                                        omertà
# 87624                    astroknots (feat. $avage)
# 122814                            when i drop this
# 119884                                   jb jr rap
# 62809                                      bossman
# 128593                           out for the night
#
#                               artist  \
# 810                        rich gang
# 67199                      tray loop
# 77510   cute girls doing cute things
# 8268               waka flocka flame
# 35280                   froggy fresh
# 51683                          sauve
# 18810                            blu
# 110542              andre xcellence!
# 177                           future
# 103908                    rico nasty
# 67124                         tyrant
# 125634                         quavo
# 3784                           drake
# 122973    youngboy never broke again
# 3999                           drake
# 87624                           phix
# 122814                  fabian mazur
# 119884                   tenacious d
# 62809                     bass reevz
# 128593                     21 savage
#
#                                                           url danceability  \
# 810     https://open.spotify.com/track/5TEJdGAiRJgAbIwFzhZnZT        0.753
# 67199   https://open.spotify.com/track/0I5Uf88cwQCP98BVwpQbar        0.755
# 77510   https://open.spotify.com/track/7Izt8YhdGjJYFoKxJqQnlm        0.742
# 8268    https://open.spotify.com/track/18zTEdaEMjZKxPFYCNienp        0.659
# 35280   https://open.spotify.com/track/7rAeTBkeWUigkMbNnIbzaz        0.797
# 51683   https://open.spotify.com/track/2wV9a6E4x3yAUBZB1A785K        0.731
# 18810   https://open.spotify.com/track/5qk9zJjTrVW3vu6Jd5uIRv        0.747
# 110542  https://open.spotify.com/track/5dDH2DoVcBw1Ldn1pSqIlx        0.682
# 177     https://open.spotify.com/track/20fAoPjfYltmd3K3bO7gbt        0.729
