# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
import json
 
f = open('keys.json')

data = json.load(f)
clientID = data['ClientID2']
ClientSecret = data['ClientSecret2']

# authentication 
credentials = SpotifyClientCredentials(client_id=clientID, client_secret=ClientSecret)
sp = spotipy.Spotify(auth_manager=credentials,retries=3000000, status_retries=3000000)

# %%
def userToPlaylistList(username):
    userPlaylists = sp.user_playlists(username)["items"]
    userLinks = []
    for i in userPlaylists:
        userLinks.append(i["external_urls"]["spotify"])
    return userLinks

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Assuming you have set up the Spotify API client
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id="YOUR_CLIENT_ID", client_secret="YOUR_CLIENT_SECRET"))

def playlistData(url):
    playlistUri = url.split("/")[-1].split("?")[0]
    offset = 0
    limit = 100

    column_names = [
        'name',
        'artist',
        'album',
        'danceability',
        'energy',
        'key',
        'loudness',
        'mode',
        'speechiness',
        'acousticness',
        'instrumentalness',
        'liveness',
        'valence',
        'tempo'
    ]

    playlistDf = pd.DataFrame(columns=column_names)

    while True:
        # Fetching a batch of tracks from the playlist
        response = sp.playlist_tracks(playlistUri, offset=offset, limit=limit, fields='items.track(name,artists,name,album,name,external_urls(spotify)),next')
        listOfTracks = response['items']
        
        # Extract the track data and audio features
        for i, item in enumerate(listOfTracks):
            track = item['track']
            if 'spotify' in track['external_urls']:
                url = track['external_urls']['spotify']
                artistName = track['artists'][0]['name']
                trackName = track['name']
                albumName = track['album']['name']
                audioFeatures = sp.audio_features([url])[0]
                rowData = [trackName, artistName, albumName, audioFeatures['danceability'], audioFeatures['energy'],
                           audioFeatures['key'], audioFeatures['loudness'], audioFeatures['mode'], audioFeatures['speechiness'],
                           audioFeatures['acousticness'], audioFeatures['instrumentalness'], audioFeatures['liveness'],
                           audioFeatures['valence'], audioFeatures['tempo']]
                playlistDf.loc[len(playlistDf)] = rowData
        
        # Check if there are more tracks to fetch
        if response['next'] is not None:
            offset += limit
        else:
            break

    return playlistDf

# Call the function with your playlist URL
playlist_df = playlistData('https://open.spotify.com/playlist/3WYzUOxaLBfBdtnuD9ojZj')
playlist_df.to_csv("./data/drake.csv")


print(playlist_df)
# Out:
#                           name       artist  \
# 0        Keep The Family Close        Drake
# 1                            9        Drake
# 2                   U With Me?        Drake
# 3                 Feel No Ways        Drake
# 4                         Hype        Drake
# ..                         ...          ...
# 466              The Shoe Fits        Drake
# 467                   Wick Man        Drake
# 468  Evil Ways (feat. J. Cole)        Drake
# 469         You Broke My Heart        Drake
# 470       Needle (feat. Drake)  Nicki Minaj
#
#                                     album  danceability  energy  key  \
# 0                                   Views         0.378   0.566    9
# 1                                   Views         0.680   0.712   10
# 2                                   Views         0.429   0.430    2
# 3                                   Views         0.582   0.677    7
# 4                                   Views         0.787   0.635    4
# ...

# %%
# code to generate allPlaylists

allDrakeUrl = "https://open.spotify.com/playlist/3WYzUOxaLBfBdtnuD9ojZj"
pureCloutUrl = "https://open.spotify.com/playlist/6oMsViRlMbV1v5a7OElr5Q"
keedGotitUrl = "https://open.spotify.com/playlist/4RLGZBY7LKHj79L0JnOGgw?si=796eb0b6a66848cf"
drillPlaylist = "https://open.spotify.com/playlist/652TD735fW0JesE9VgHhzS"
babyPlaylist = "https://open.spotify.com/playlist/07Sme1haQzeuVpDIFqB1im"
futurePlaylist = "https://open.spotify.com/playlist/3TnojI5pv8nedMq3V1VXEU"
smoovePlaylist = "https://open.spotify.com/playlist/6IjIyQ6tsb2nTZKLfi2UBw"
yslPlaylist = "https://open.spotify.com/playlist/1SArKCuRKftWQ9x7cIwD3w?si=d6dffa983cfb40f3"

users = ['12176828559','bikramkohli007','crazydoc1','jamesl3248','eric_chungg','johnwarzecha-us','1270601874']

allPlaylists = [allDrakeUrl,pureCloutUrl,keedGotitUrl,drillPlaylist,babyPlaylist,futurePlaylist,smoovePlaylist,yslPlaylist]
for user in users:
    allPlaylists += userToPlaylistList(user)
# Out:
# https://open.spotify.com/track/7sBwAWyXfiIgrYQ8BaJESH
# [{'danceability': 0.378, 'energy': 0.566, 'key': 9, 'loudness': -7.685, 'mode': 0, 'speechiness': 0.0482, 'acousticness': 0.149, 'instrumentalness': 0, 'liveness': 0.382, 'valence': 0.196, 'tempo': 87.691, 'type': 'audio_features', 'id': '7sBwAWyXfiIgrYQ8BaJESH', 'uri': 'spotify:track:7sBwAWyXfiIgrYQ8BaJESH', 'track_href': 'https://api.spotify.com/v1/tracks/7sBwAWyXfiIgrYQ8BaJESH', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sBwAWyXfiIgrYQ8BaJESH', 'duration_ms': 328907, 'time_signature': 3}]
# None

# %%
allPlaylists = ['https://open.spotify.com/playlist/3WYzUOxaLBfBdtnuD9ojZj', 'https://open.spotify.com/playlist/6oMsViRlMbV1v5a7OElr5Q', 'https://open.spotify.com/playlist/4RLGZBY7LKHj79L0JnOGgw?si=796eb0b6a66848cf', 'https://open.spotify.com/playlist/652TD735fW0JesE9VgHhzS', 'https://open.spotify.com/playlist/07Sme1haQzeuVpDIFqB1im', 'https://open.spotify.com/playlist/3TnojI5pv8nedMq3V1VXEU', 'https://open.spotify.com/playlist/6IjIyQ6tsb2nTZKLfi2UBw', 'https://open.spotify.com/playlist/1SArKCuRKftWQ9x7cIwD3w?si=d6dffa983cfb40f3', 'https://open.spotify.com/playlist/22UzZj4WfDH6IhXF4psWFg', 'https://open.spotify.com/playlist/4zVL8AUIUpuQU5G6EWPaAb', 'https://open.spotify.com/playlist/3QLBRhTdciJIGOqLzXXhpU', 'https://open.spotify.com/playlist/33PIJ4bhVgkOzyW5cKepM6', 'https://open.spotify.com/playlist/2mqCkzRnf8BeiiqUhPY3h9', 'https://open.spotify.com/playlist/5zzUE6c1cNkHDQJGRJgczW', 'https://open.spotify.com/playlist/3TaIu5uO14Jt62joLsBpZl', 'https://open.spotify.com/playlist/1TwnKFgnNIYSc4UkEoOFOa', 'https://open.spotify.com/playlist/1zVSLuZ9F0k9DVptn929i0', 'https://open.spotify.com/playlist/3Rt8VjHDzP8Qsxy3ArfHjP', 'https://open.spotify.com/playlist/4vwaNfVs5PxfEm219QVwSo', 'https://open.spotify.com/playlist/62Zo6sumbj4RMuvV5DDmZi', 'https://open.spotify.com/playlist/5RzFxATCIzjpYcSNNNK8vl', 'https://open.spotify.com/playlist/7ce7bb7ore4m1gdMNZ9F9u', 'https://open.spotify.com/playlist/6onKYWwhWX7Bve0MpXMm3g', 'https
 'https://open.spotify.com/playlist/5XzA3EgjYfEp2AVpLqaIH0', 'https://open.spotify.com/playlist/6fs2wwnCtA6W62ZBXbYWla', 'https://open.spotify.com/playlist/6KIEAvvGWUMO1ruRf60p0V', 'https://open.spotify.com/playlist/1E63c2LQ9QM2WUv675iekp', 'https://open.spotify.com/playlist/5VfEEKfnMgOftRKRLGG6HJ', 'https://open.spotify.com/playlist/6gpkXhva4UjovRrNzsY81j', 'https://open.spotify.com/playlist/79c4KM5MIELAbzykzXOA9l', 'https://open.spotify.com/playlist/7vf0Ps6xXKTxCqBPyTn9GM', 'https://open.spotify.com/playlist/7EyyK5uhqLsO2qQDG2539E', 'https://open.spotify.com/playlist/7kc5BOhfd2ucoVqgNnO8BT', 'https://open.spotify.com/playlist/3SLCFocdrHWdx3lYdr91Ro', 'https://open.spotify.com/playlist/6T9GUxlyN6mGFE97npkANB', 'https://open.spotify.com/playlist/0sTAK1UvXlUOJhnjM5hQcm', 'https://open.spotify.com/playlist/2OvRin8vpmkQ7p2i8mdybD', 'https://open.spotify.com/playlist/7yiXpZsYtYWZTgMQEZFLcP', 'https://open.spotify.com/playlist/76XUecCXRGdcGYH5niZGjp', 'https://open.spotify.com/playlist/7rlmS5wqfE51OZ0EDIzkLf', 'https://open.spotify.com/playlist/2iWzZOPv1N9jhcP50l2xGv', 'https://open.spotify.com/playlist/3CRmmyEVo1KdNISpuZukJs', 'https://open.spotify.com/playlist/7a0i0oTFOUqtFkevxJSGTP', 'https://open.spotify.com/playlist/3dpBFPX3wnXHAcMkFY8qCa', 'https://open.spotify.com/playlist/68SvT6K6htyZtoG4OCZDZC', 'https://open.spotify.com/playlist/2CDA05gSb6NcX2Em7lrORm', 'https://open.spotify.com/playlist/1PTS53cKxyWUBq2B4zvQAY', 'https://open.spotify.com/playlist/5zDVVZH7p5JJTR3S1kAbuF', 'https://open.spotify.com/playlist/0Hr9xYBGSZyrfPxe3i0iSx', 'https://open.spotify.com/playlist/2SkIVr9gDtJoNRIgXw2kGL', 'https://open.spotify.com/playlist/5buP5CNU6fCVo9MqBMVUGa', 'https://open.spotify.com/playlist/2qVVLwqabzVIWdY2mjQCiu', 'https://open.spotify.com/playlist/0jqs8DqBwFTkaj5lxqzMR8', 'https://open.spotify.com/playlist/0kgYACIpddYywBToMDjzLV', 'https://open.spotify.com/playlist/6FosmxLdXt5siQIoD6iONw', 'https://open.spotify.com/playlist/6j0L1wJQcvYILjcXZa7XVn', 'https://open.spotify.com/playlist/2JELmbcjGyG3M01i5ByN0L', 'https://open.spotify.com/playlist/4jA9gCASCuFMMiK3SiRVd8', 'https://open.spotify.com/playlist/0uJKIzqsx6igK1HFFg3bjS', 'https://open.spotify.com/playlist/2XyLj5rkIXBAFNvAyqmgkX', 'https://open.spotify.com/playlist/3MViNcu4L2COD4YXAW8jA7', 'https://open.spotify.com/playlist/4ylfedvUi1JZ2QqkqL7Nvb', 'https://open.spotify.com/playlist/5SMiDeq9UmP7DnVItqgVDE', 'https://open.spotify.com/playlist/16v82Emf01SrPa8SdpHLLY']
print(playlistData(allPlaylists[0]))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
# Out:
# ['br', 'e']
